# %%
from RelGAN import *
from dataset import make_data_generator
import json
from tqdm import tqdm_notebook as tqdm
import os
#from torchsummary import summary

# %%
folder = '/tmp2/Food/'
data_name = folder+'data.json'
# validation_name = folder+'valid_seq.json'
# testdata_name = folder+'testdata_seq.json'
vocab_name = folder+'vocab.json'

# %%
num_epochs = 10
save_rate = 1 #how many epochs per modelsave
#continue_from = "trained/Model1" # if none, put None
continue_from = None
epsilon = 1e-8
validation_size = 10000
device = torch.device('cuda')
# !mkdir -p trained
os.environ['WANDB_NOTEBOOK_NAME'] = 'LSTM_GumbelSoftmax'

# %%
vocab = json.load(open(vocab_name, 'r'))
VOC_SIZE = len(vocab)
INPUT_MAX = 50
SUMM_MAX = 50
UNK = "[UNK]"
BOS = "[CLS]"
EOS = "[SEP]"
PAD = "[PAD]"

# %%
batch_size = 2

training_set, training_generator = make_data_generator(\
data_name, INPUT_MAX, SUMM_MAX, vocab[PAD], batch_size, pretrain = True, cutoff=None, shuffle=True, num_workers=4)

# validation_set, validation_generator = make_data_generator(\
# validation_name, INPUT_MAX, OUTPUT_MAX, vocab[PAD], batch_size, cutoff=validation_size, shuffle=False, num_workers=4)

def data_gen_train():
    for src, tgt in training_generator:
        src = src.to(device)
        #label = (label).long().to(device)
        tgt = tgt.to(device)
        b = Batch(src, tgt, vocab[PAD])
        #b.label = label
        yield b
# Out:
# loading json
# load json done.
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
import math
total_train = int(math.ceil(training_set.size / batch_size))
# total_valid = int(math.ceil(validation_set.size / batch_size))
# print(total_train, total_valid)

# %%
def init_param(model):
    for p in model.parameters():
        if p.dim() > 1:
            nn.init.xavier_uniform_(p)

def make_big_bird(vocab, N=6, 
               d_model=512, d_ff=2048, h=8, dropout=0.1, emb_share=False, bert_share=False):
    "Helper: Construct a model from hyperparameters."
    
    vocab_sz = len(vocab)
        
    c = copy.deepcopy
    attn = MultiHeadedAttention(h, d_model)
    ff = PositionwiseFeedForward(d_model, d_ff, dropout)
    position = PositionalEncoding(d_model, dropout)
    
    src_emb = nn.Sequential(Embeddings(d_model, vocab_sz), c(position))
    if emb_share:        
        tgt_emb = src_emb
        bert_class_emb = src_emb
        bert_discr_emb = src_emb
    else:
        tgt_emb = nn.Sequential(Embeddings(d_model, vocab_sz), c(position))
        bert_class_emb = nn.Sequential(Embeddings(d_model, vocab_sz), c(position))
        bert_discr_emb = nn.Sequential(Embeddings(d_model, vocab_sz), c(position))
        
    translator = RelationalMemory(
        mem_slots = 1,
        head_size = 192,
        input_size = d_model,
        num_tokens = vocab_sz,
        device = device,
        num_heads = 4,
        attention_mlp_layers=3,
        key_size = 64,
        use_adaptive_softmax=True,
        cutoffs = [1000, 5000, 20000]
    )

    reconstructor = RelationalMemory(
        mem_slots = 1,
        head_size = 192,
        input_size = d_model,
        num_tokens = vocab_sz,
        device = device,
        num_heads = 4,
        attention_mlp_layers=3,
        key_size = 64,
        use_adaptive_softmax=True,
        cutoffs = [1000, 5000, 20000]
    )
#     reconstructor = LSTM_Normal_Encoder_Decoder(
#         hidden_dim=d_model, 
#         emb_dim=d_model, 
#         input_len=SUMM_MAX, 
#         output_len=INPUT_MAX, 
#         voc_size=vocab_sz, 
#         pad_index=vocab[PAD],
#         device = device,
#         eps=1e-8,
#         num_layers = 2
#     )
 
    discriminator = Discriminator(
        Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N),
        d_model,
        len(vocab),
        vocab[PAD]
    )


    # This was important from their code. 
    # Initialize parameters with Glorot / fan_avg.
    for m in [translator, reconstructor, discriminator]:
        init_param(m)
            
    # creation of big bird
    model = BigBird(
        translator, discriminator, reconstructor , 
        vocab, gamma=0.99, clip_value=0.5, #for WGAN, useless if WGAN-GP is used 
        lr_G = 5e-5,
        lr_D = 1e-4,
        lr_R = 5e-5,
        LAMBDA = 10, # Gradient penalty lambda hyperparameter
        TEMP_END = 0.5,
        device = device
    )

    return model

# %%
model = make_big_bird(vocab, N=4, d_model=256, d_ff=256, h=4, dropout=0.1, emb_share=True, bert_share=True)
#model.load("Nest/NewbornBird_LSTM_GumbelSoftmax")

# %%
vocab_inv = {a:b for b, a in vocab.items()}
def convert_ids_to_tokens(ids):
    return [vocab_inv[i] for i in ids]

# %%
import wandb
import matplotlib.pyplot as plt
import matplotlib

wandb.init(project="seq2seq-discrete-encoder-decoder")
wandb.config.update({
    "batch_size": batch_size,
    "input len":INPUT_MAX,
    "summary len":SUMM_MAX,
    "lr_G":model.lr_G,
    "lr_D":model.lr_D,
    "lr_R":model.lr_R,
    "temperature min":model.TEMP_END,
    })
wandb.watch([model.generator, model.discriminator, model.reconstructor])
#ecc70f422dabf793a9101343c84e8ead3c0bf72e
# Out:
#         Notebook configured with <a href="https://wandb.com" target="_blank">W&B</a>. You can <a href="https://app.wandb.ai/marvin852316497/seq2seq-discrete-encoder-decoder/runs/3la78eqe" target="_blank">open</a> the run page, or call <code>%%wandb</code>
#         in a cell containing your training loop to display live results.  Learn more in our <a href="https://docs.wandb.com/docs/integrations/jupyter.html" target="_blank">docs</a>.
# [<wandb.wandb_torch.TorchGraph at 0x7f9bbc0515d0>,
#  <wandb.wandb_torch.TorchGraph at 0x7f9bb014afd0>,
#  <wandb.wandb_torch.TorchGraph at 0x7f9bb011c550>]

# %%
#start = 1 if continue_from == None else (int(continue_from.split("Model")[-1])+1)
history = []

start = model.epoch

#from tensorboardX import SummaryWriter
#writer = SummaryWriter('mygraph')

step_ct = 1
width = 0.35



for epoch in range(start, num_epochs+1):
    print("Epoch", epoch)
    
    # training
    stats = Stats()
    model.train()
    
    rewards = []
    
    trange = tqdm(enumerate(data_gen_train()), total=total_train)
    for i, batch in trange:
        #expect src has [CLS] and [SEP]
        #batch.trg.shape[1] is for dataset
        GAN_loss, Rec_loss, score, output, distrib, one_hot = model.pretrainGAN_run_iter(batch.src, batch.src_mask, batch.trg.shape[1], batch.trg, D_iters=5, D_toggle = 'Off', verbose = 0)
        trange.set_postfix(
            **{'G_loss': '{:.3f}'.format(GAN_loss[0])},
            **{'D_loss': '{:.3f}'.format(GAN_loss[1])},
            **{'CE_loss': '{:.3f}'.format(Rec_loss[0])},
            #**{'vq_loss': '{:.3f}'.format(Rec_loss[1])},
            #**{'commit_loss': '{:.3f}'.format(Rec_loss[2])},
            **{'real_score': '{:.3f}'.format(score[0])},
            **{'fake_score': '{:.3f}'.format(score[1])},
            **{'acc': '{:.3f}'.format(score[2])},
        )

        if step_ct % 50 == 0:
            
            x = np.arange(len(distrib))
            ratio = 1.0/max(distrib)
            plt.bar(x, ratio * distrib, label='distrib hist' , align = "edge", width = width)
            plt.bar(x, one_hot, label='Gumbel softmax hist' , align = "edge", width = -width)
            
            plt.legend()
            plt.title("distrib vs gumbel sample (max distrib is upscale to 1)")
            plt.xlabel("dictionary [:100]")
            plt.ylabel("prob")
            wandb.log({"hist":wandb.Image(plt)})
            plt.clf()


            
            
        wandb.log({"input":output[0],
                   "encode out":output[1],
                   "reconsturct out":output[2],        
                  })
        wandb.log({
                   "G_loss":GAN_loss[0],
                   "D_loss":GAN_loss[1],
                   "CE_loss":Rec_loss[0],
                   #"vq_loss":Rec_loss[1],
                   #"commit_loss":Rec_loss[2],
                   "real_score":score[0],
                   "fake_score":score[1],
                   "acc":score[2],
                   "gumbel temperature":model.gumbel_temperature
                  }, commit=False)
            
        step_ct += 1
    model.epoch += 1
# Out:
# Epoch 0
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 47])
# torch.Size([2, 46, 100000])
# torch.Size([2, 46])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 24])
# torch.Size([2, 23, 100000])
# torch.Size([2, 23])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 46])
# torch.Size([2, 45, 100000])
# torch.Size([2, 45])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 47])
# torch.Size([2, 46, 100000])
# torch.Size([2, 46])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 34])
# torch.Size([2, 33, 100000])
# torch.Size([2, 33])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 32])
# torch.Size([2, 31, 100000])
# torch.Size([2, 31])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 41])
# torch.Size([2, 40, 100000])
# torch.Size([2, 40])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 48])
# torch.Size([2, 47, 100000])
# torch.Size([2, 47])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 39])
# torch.Size([2, 38, 100000])
# torch.Size([2, 38])
# torch.Size([2, 47])
# torch.Size([2, 46, 100000])
# torch.Size([2, 46])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 24])
# torch.Size([2, 23, 100000])
# torch.Size([2, 23])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 40])
# torch.Size([2, 39, 100000])
# torch.Size([2, 39])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 41])
# torch.Size([2, 40, 100000])
# torch.Size([2, 40])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 38])
# torch.Size([2, 37, 100000])
# torch.Size([2, 37])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 35])
# torch.Size([2, 34, 100000])
# torch.Size([2, 34])
# torch.Size([2, 38])
# torch.Size([2, 37, 100000])
# torch.Size([2, 37])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 48])
# torch.Size([2, 47, 100000])
# torch.Size([2, 47])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 32])
# torch.Size([2, 31, 100000])
# torch.Size([2, 31])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 37])
# torch.Size([2, 36, 100000])
# torch.Size([2, 36])
# torch.Size([2, 26])
# torch.Size([2, 25, 100000])
# torch.Size([2, 25])
# torch.Size([2, 38])
# torch.Size([2, 37, 100000])
# torch.Size([2, 37])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 32])
# torch.Size([2, 31, 100000])
# torch.Size([2, 31])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 27])
# torch.Size([2, 26, 100000])
# torch.Size([2, 26])
# torch.Size([2, 39])
# torch.Size([2, 38, 100000])
# torch.Size([2, 38])
# torch.Size([2, 49])
# torch.Size([2, 48, 100000])
# torch.Size([2, 48])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 48])
# torch.Size([2, 47, 100000])
# torch.Size([2, 47])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 48])
# torch.Size([2, 47, 100000])
# torch.Size([2, 47])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 27])
# torch.Size([2, 26, 100000])
# torch.Size([2, 26])
# torch.Size([2, 28])
# torch.Size([2, 27, 100000])
# torch.Size([2, 27])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 41])
# torch.Size([2, 40, 100000])
# torch.Size([2, 40])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 28])
# torch.Size([2, 27, 100000])
# torch.Size([2, 27])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 46])
# torch.Size([2, 45, 100000])
# torch.Size([2, 45])
# torch.Size([2, 45])
# torch.Size([2, 44, 100000])
# torch.Size([2, 44])
# torch.Size([2, 40])
# torch.Size([2, 39, 100000])
# torch.Size([2, 39])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 28])
# torch.Size([2, 27, 100000])
# torch.Size([2, 27])
# torch.Size([2, 48])
# torch.Size([2, 47, 100000])
# torch.Size([2, 47])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 26])
# torch.Size([2, 25, 100000])
# torch.Size([2, 25])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 44])
# torch.Size([2, 43, 100000])
# torch.Size([2, 43])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 28])
# torch.Size([2, 27, 100000])
# torch.Size([2, 27])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 23])
# torch.Size([2, 22, 100000])
# torch.Size([2, 22])
# torch.Size([2, 39])
# torch.Size([2, 38, 100000])
# torch.Size([2, 38])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 38])
# torch.Size([2, 37, 100000])
# torch.Size([2, 37])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 30])
# torch.Size([2, 29, 100000])
# torch.Size([2, 29])
# torch.Size([2, 43])
# torch.Size([2, 42, 100000])
# torch.Size([2, 42])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 32])
# torch.Size([2, 31, 100000])
# torch.Size([2, 31])
# torch.Size([2, 44])
# torch.Size([2, 43, 100000])
# torch.Size([2, 43])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 29])
# torch.Size([2, 28, 100000])
# torch.Size([2, 28])
# torch.Size([2, 32])
# torch.Size([2, 31, 100000])
# torch.Size([2, 31])
# torch.Size([2, 30])
# torch.Size([2, 29, 100000])
# torch.Size([2, 29])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 29])
# torch.Size([2, 28, 100000])
# torch.Size([2, 28])
# torch.Size([2, 35])
# torch.Size([2, 34, 100000])
# torch.Size([2, 34])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 32])
# torch.Size([2, 31, 100000])
# torch.Size([2, 31])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 26])
# torch.Size([2, 25, 100000])
# torch.Size([2, 25])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 35])
# torch.Size([2, 34, 100000])
# torch.Size([2, 34])
# torch.Size([2, 31])
# torch.Size([2, 30, 100000])
# torch.Size([2, 30])
# torch.Size([2, 35])
# torch.Size([2, 34, 100000])
# torch.Size([2, 34])
# torch.Size([2, 26])
# torch.Size([2, 25, 100000])
# torch.Size([2, 25])
# torch.Size([2, 31])
# torch.Size([2, 30, 100000])
# torch.Size([2, 30])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 29])
# torch.Size([2, 28, 100000])
# torch.Size([2, 28])
# torch.Size([2, 44])
# torch.Size([2, 43, 100000])
# torch.Size([2, 43])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 45])
# torch.Size([2, 44, 100000])
# torch.Size([2, 44])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 30])
# torch.Size([2, 29, 100000])
# torch.Size([2, 29])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 21])
# torch.Size([2, 20, 100000])
# torch.Size([2, 20])
# torch.Size([2, 39])
# torch.Size([2, 38, 100000])
# torch.Size([2, 38])
# torch.Size([2, 36])
# torch.Size([2, 35, 100000])
# torch.Size([2, 35])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 46])
# torch.Size([2, 45, 100000])
# torch.Size([2, 45])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 45])
# torch.Size([2, 44, 100000])
# torch.Size([2, 44])
# torch.Size([2, 42])
# torch.Size([2, 41, 100000])
# torch.Size([2, 41])
# torch.Size([2, 46])
# torch.Size([2, 45, 100000])
# torch.Size([2, 45])
# torch.Size([2, 37])
# torch.Size([2, 36, 100000])
# torch.Size([2, 36])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 35])
# torch.Size([2, 34, 100000])
# torch.Size([2, 34])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 49])
# torch.Size([2, 48, 100000])
# torch.Size([2, 48])
# torch.Size([2, 42])
# torch.Size([2, 41, 100000])
# torch.Size([2, 41])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 40])
# torch.Size([2, 39, 100000])
# torch.Size([2, 39])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 44])
# torch.Size([2, 43, 100000])
# torch.Size([2, 43])
# torch.Size([2, 49])
# torch.Size([2, 48, 100000])
# torch.Size([2, 48])
# torch.Size([2, 42])
# torch.Size([2, 41, 100000])
# torch.Size([2, 41])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 29])
# torch.Size([2, 28, 100000])
# torch.Size([2, 28])
# torch.Size([2, 40])
# torch.Size([2, 39, 100000])
# torch.Size([2, 39])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 41])
# torch.Size([2, 40, 100000])
# torch.Size([2, 40])
# torch.Size([2, 24])
# torch.Size([2, 23, 100000])
# torch.Size([2, 23])
# torch.Size([2, 42])
# torch.Size([2, 41, 100000])
# torch.Size([2, 41])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 26])
# torch.Size([2, 25, 100000])
# torch.Size([2, 25])
# torch.Size([2, 32])
# torch.Size([2, 31, 100000])
# torch.Size([2, 31])
# torch.Size([2, 45])
# torch.Size([2, 44, 100000])
# torch.Size([2, 44])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 27])
# torch.Size([2, 26, 100000])
# torch.Size([2, 26])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 44])
# torch.Size([2, 43, 100000])
# torch.Size([2, 43])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 38])
# torch.Size([2, 37, 100000])
# torch.Size([2, 37])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 45])
# torch.Size([2, 44, 100000])
# torch.Size([2, 44])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 27])
# torch.Size([2, 26, 100000])
# torch.Size([2, 26])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 39])
# torch.Size([2, 38, 100000])
# torch.Size([2, 38])
# torch.Size([2, 33])
# torch.Size([2, 32, 100000])
# torch.Size([2, 32])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 27])
# torch.Size([2, 26, 100000])
# torch.Size([2, 26])
# torch.Size([2, 24])
# torch.Size([2, 23, 100000])
# torch.Size([2, 23])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 26])
# torch.Size([2, 25, 100000])
# torch.Size([2, 25])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 33])
# torch.Size([2, 32, 100000])
# torch.Size([2, 32])
# torch.Size([2, 35])
# torch.Size([2, 34, 100000])
# torch.Size([2, 34])
# torch.Size([2, 28])
# torch.Size([2, 27, 100000])
# torch.Size([2, 27])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 41])
# torch.Size([2, 40, 100000])
# torch.Size([2, 40])
# torch.Size([2, 36])
# torch.Size([2, 35, 100000])
# torch.Size([2, 35])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 35])
# torch.Size([2, 34, 100000])
# torch.Size([2, 34])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 38])
# torch.Size([2, 37, 100000])
# torch.Size([2, 37])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 34])
# torch.Size([2, 33, 100000])
# torch.Size([2, 33])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 30])
# torch.Size([2, 29, 100000])
# torch.Size([2, 29])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 33])
# torch.Size([2, 32, 100000])
# torch.Size([2, 32])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 34])
# torch.Size([2, 33, 100000])
# torch.Size([2, 33])
# torch.Size([2, 31])
# torch.Size([2, 30, 100000])
# torch.Size([2, 30])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 44])
# torch.Size([2, 43, 100000])
# torch.Size([2, 43])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 35])
# torch.Size([2, 34, 100000])
# torch.Size([2, 34])
# torch.Size([2, 30])
# torch.Size([2, 29, 100000])
# torch.Size([2, 29])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 33])
# torch.Size([2, 32, 100000])
# torch.Size([2, 32])
# torch.Size([2, 27])
# torch.Size([2, 26, 100000])
# torch.Size([2, 26])
# torch.Size([2, 30])
# torch.Size([2, 29, 100000])
# torch.Size([2, 29])
# torch.Size([2, 49])
# torch.Size([2, 48, 100000])
# torch.Size([2, 48])
# torch.Size([2, 23])
# torch.Size([2, 22, 100000])
# torch.Size([2, 22])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 40])
# torch.Size([2, 39, 100000])
# torch.Size([2, 39])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 36])
# torch.Size([2, 35, 100000])
# torch.Size([2, 35])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 35])
# torch.Size([2, 34, 100000])
# torch.Size([2, 34])
# torch.Size([2, 27])
# torch.Size([2, 26, 100000])
# torch.Size([2, 26])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 40])
# torch.Size([2, 39, 100000])
# torch.Size([2, 39])
# torch.Size([2, 31])
# torch.Size([2, 30, 100000])
# torch.Size([2, 30])
# torch.Size([2, 37])
# torch.Size([2, 36, 100000])
# torch.Size([2, 36])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 24])
# torch.Size([2, 23, 100000])
# torch.Size([2, 23])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 47])
# torch.Size([2, 46, 100000])
# torch.Size([2, 46])
# torch.Size([2, 40])
# torch.Size([2, 39, 100000])
# torch.Size([2, 39])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 42])
# torch.Size([2, 41, 100000])
# torch.Size([2, 41])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 27])
# torch.Size([2, 26, 100000])
# torch.Size([2, 26])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 41])
# torch.Size([2, 40, 100000])
# torch.Size([2, 40])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 47])
# torch.Size([2, 46, 100000])
# torch.Size([2, 46])
# torch.Size([2, 20])
# torch.Size([2, 19, 100000])
# torch.Size([2, 19])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 25])
# torch.Size([2, 24, 100000])
# torch.Size([2, 24])
# torch.Size([2, 43])
# torch.Size([2, 42, 100000])
# torch.Size([2, 42])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 27])
# torch.Size([2, 26, 100000])
# torch.Size([2, 26])
# torch.Size([2, 40])
# torch.Size([2, 39, 100000])
# torch.Size([2, 39])
# torch.Size([2, 49])
# torch.Size([2, 48, 100000])
# torch.Size([2, 48])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 31])
# torch.Size([2, 30, 100000])
# torch.Size([2, 30])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 33])
# torch.Size([2, 32, 100000])
# torch.Size([2, 32])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 30])
# torch.Size([2, 29, 100000])
# torch.Size([2, 29])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 49])
# torch.Size([2, 48, 100000])
# torch.Size([2, 48])
# torch.Size([2, 33])
# torch.Size([2, 32, 100000])
# torch.Size([2, 32])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 37])
# torch.Size([2, 36, 100000])
# torch.Size([2, 36])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 45])
# torch.Size([2, 44, 100000])
# torch.Size([2, 44])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 44])
# torch.Size([2, 43, 100000])
# torch.Size([2, 43])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 23])
# torch.Size([2, 22, 100000])
# torch.Size([2, 22])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 31])
# torch.Size([2, 30, 100000])
# torch.Size([2, 30])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 43])
# torch.Size([2, 42, 100000])
# torch.Size([2, 42])
# torch.Size([2, 18])
# torch.Size([2, 17, 100000])
# torch.Size([2, 17])
# torch.Size([2, 24])
# torch.Size([2, 23, 100000])
# torch.Size([2, 23])
# torch.Size([2, 30])
# torch.Size([2, 29, 100000])
# torch.Size([2, 29])
# torch.Size([2, 25])
# torch.Size([2, 24, 100000])
# torch.Size([2, 24])
# torch.Size([2, 26])
# torch.Size([2, 25, 100000])
# torch.Size([2, 25])
# torch.Size([2, 21])
# torch.Size([2, 20, 100000])
# torch.Size([2, 20])
# torch.Size([2, 47])
# torch.Size([2, 46, 100000])
# torch.Size([2, 46])
# torch.Size([2, 29])
# torch.Size([2, 28, 100000])
# torch.Size([2, 28])
# torch.Size([2, 37])
# torch.Size([2, 36, 100000])
# torch.Size([2, 36])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 31])
# torch.Size([2, 30, 100000])
# torch.Size([2, 30])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 48])
# torch.Size([2, 47, 100000])
# torch.Size([2, 47])
# torch.Size([2, 38])
# torch.Size([2, 37, 100000])
# torch.Size([2, 37])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 36])
# torch.Size([2, 35, 100000])
# torch.Size([2, 35])
# torch.Size([2, 47])
# torch.Size([2, 46, 100000])
# torch.Size([2, 46])
# torch.Size([2, 29])
# torch.Size([2, 28, 100000])
# torch.Size([2, 28])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 38])
# torch.Size([2, 37, 100000])
# torch.Size([2, 37])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 29])
# torch.Size([2, 28, 100000])
# torch.Size([2, 28])
# torch.Size([2, 22])
# torch.Size([2, 21, 100000])
# torch.Size([2, 21])
# torch.Size([2, 30])
# torch.Size([2, 29, 100000])
# torch.Size([2, 29])
# torch.Size([2, 34])
# torch.Size([2, 33, 100000])
# torch.Size([2, 33])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 23])
# torch.Size([2, 22, 100000])
# torch.Size([2, 22])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 43])
# torch.Size([2, 42, 100000])
# torch.Size([2, 42])
# torch.Size([2, 28])
# torch.Size([2, 27, 100000])
# torch.Size([2, 27])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 42])
# torch.Size([2, 41, 100000])
# torch.Size([2, 41])
# torch.Size([2, 45])
# torch.Size([2, 44, 100000])
# torch.Size([2, 44])
# torch.Size([2, 28])
# torch.Size([2, 27, 100000])
# torch.Size([2, 27])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 19])
# torch.Size([2, 18, 100000])
# torch.Size([2, 18])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 44])
# torch.Size([2, 43, 100000])
# torch.Size([2, 43])
# torch.Size([2, 27])
# torch.Size([2, 26, 100000])
# torch.Size([2, 26])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 41])
# torch.Size([2, 40, 100000])
# torch.Size([2, 40])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 32])
# torch.Size([2, 31, 100000])
# torch.Size([2, 31])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 33])
# torch.Size([2, 32, 100000])
# torch.Size([2, 32])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 39])
# torch.Size([2, 38, 100000])
# torch.Size([2, 38])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 21])
# torch.Size([2, 20, 100000])
# torch.Size([2, 20])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 44])
# torch.Size([2, 43, 100000])
# torch.Size([2, 43])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 27])
# torch.Size([2, 26, 100000])
# torch.Size([2, 26])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 35])
# torch.Size([2, 34, 100000])
# torch.Size([2, 34])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 29])
# torch.Size([2, 28, 100000])
# torch.Size([2, 28])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 28])
# torch.Size([2, 27, 100000])
# torch.Size([2, 27])
# torch.Size([2, 42])
# torch.Size([2, 41, 100000])
# torch.Size([2, 41])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 39])
# torch.Size([2, 38, 100000])
# torch.Size([2, 38])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 34])
# torch.Size([2, 33, 100000])
# torch.Size([2, 33])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 33])
# torch.Size([2, 32, 100000])
# torch.Size([2, 32])
# lay egg to ./Nest ... save as ./Nest/Pretrain_RelGAN
#
# Epoch 1
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# torch.Size([2, 48])
# torch.Size([2, 47, 100000])
# torch.Size([2, 47])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 49])
# torch.Size([2, 48, 100000])
# torch.Size([2, 48])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 41])
# torch.Size([2, 40, 100000])
# torch.Size([2, 40])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 28])
# torch.Size([2, 27, 100000])
# torch.Size([2, 27])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 42])
# torch.Size([2, 41, 100000])
# torch.Size([2, 41])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 30])
# torch.Size([2, 29, 100000])
# torch.Size([2, 29])
# torch.Size([2, 29])
# torch.Size([2, 28, 100000])
# torch.Size([2, 28])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 38])
# torch.Size([2, 37, 100000])
# torch.Size([2, 37])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 41])
# torch.Size([2, 40, 100000])
# torch.Size([2, 40])
# torch.Size([2, 47])
# torch.Size([2, 46, 100000])
# torch.Size([2, 46])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 48])
# torch.Size([2, 47, 100000])
# torch.Size([2, 47])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 34])
# torch.Size([2, 33, 100000])
# torch.Size([2, 33])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 36])
# torch.Size([2, 35, 100000])
# torch.Size([2, 35])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 41])
# torch.Size([2, 40, 100000])
# torch.Size([2, 40])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 38])
# torch.Size([2, 37, 100000])
# torch.Size([2, 37])
# torch.Size([2, 31])
# torch.Size([2, 30, 100000])
# torch.Size([2, 30])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 30])
# torch.Size([2, 29, 100000])
# torch.Size([2, 29])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 42])
# torch.Size([2, 41, 100000])
# torch.Size([2, 41])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 31])
# torch.Size([2, 30, 100000])
# torch.Size([2, 30])
# torch.Size([2, 33])
# torch.Size([2, 32, 100000])
# torch.Size([2, 32])
# torch.Size([2, 33])
# torch.Size([2, 32, 100000])
# torch.Size([2, 32])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 47])
# torch.Size([2, 46, 100000])
# torch.Size([2, 46])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 23])
# torch.Size([2, 22, 100000])
# torch.Size([2, 22])
# torch.Size([2, 49])
# torch.Size([2, 48, 100000])
# torch.Size([2, 48])
# torch.Size([2, 19])
# torch.Size([2, 18, 100000])
# torch.Size([2, 18])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 43])
# torch.Size([2, 42, 100000])
# torch.Size([2, 42])
# torch.Size([2, 49])
# torch.Size([2, 48, 100000])
# torch.Size([2, 48])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 26])
# torch.Size([2, 25, 100000])
# torch.Size([2, 25])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 33])
# torch.Size([2, 32, 100000])
# torch.Size([2, 32])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 29])
# torch.Size([2, 28, 100000])
# torch.Size([2, 28])
# torch.Size([2, 44])
# torch.Size([2, 43, 100000])
# torch.Size([2, 43])
# torch.Size([2, 35])
# torch.Size([2, 34, 100000])
# torch.Size([2, 34])
# torch.Size([2, 48])
# torch.Size([2, 47, 100000])
# torch.Size([2, 47])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 35])
# torch.Size([2, 34, 100000])
# torch.Size([2, 34])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 24])
# torch.Size([2, 23, 100000])
# torch.Size([2, 23])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# torch.Size([2, 49, 100000])
# torch.Size([2, 49])
# torch.Size([2, 50])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-c3a0c77d967e> in <module>
#      25         #expect src has [CLS] and [SEP]
#      26         #batch.trg.shape[1] is for dataset
# ---> 27         GAN_loss, Rec_loss, score, output, distrib, one_hot = model.pretrainGAN_run_iter(batch.src, batch.src_mask, batch.trg.shape[1], batch.trg, D_iters=5, D_toggle = 'Off', verbose = 0)
#      28         trange.set_postfix(
#      29             **{'G_loss': '{:.3f}'.format(GAN_loss[0])},
#
# /nfs/undergrad/05/b05902026/Summarization-Lab/BIG-BIRD/RelGAN.py in pretrainGAN_run_iter(self, src, src_mask, max_len, real_data, D_iters, D_toggle, verbose)
#     172         self.gumbel_temperature = max(self.TEMP_END, math.exp(-1e-4*self.total_steps))
#     173         print(src.shape)
# --> 174         summary_sample, summary_log_values, summary_probs, gumbel_one_hot = self.generator(src, max_len, memory, self.dictionary['[CLS]'], temperature = self.gumbel_temperature)
#     175
#     176         batch_G_loss = 0
#
# /usr/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# /nfs/undergrad/05/b05902026/Summarization-Lab/BIG-BIRD/RelationalMemory.py in forward(self, inputs, max_len, memory, start_symbol, temperature, require_logits)
#     384         # shape[1] is seq_lenth T
#     385         for idx_step in range(inputs.shape[1]):
# --> 386             _, memory = self.forward_step(inputs[:, idx_step], memory)
#     387
#     388
#
# /nfs/undergrad/05/b05902026/Summarization-Lab/BIG-BIRD/RelationalMemory.py in forward_step(self, inputs, memory, already_embed, treat_input_as_matrix)
#     345         if self.gate_style == 'unit' or self.gate_style == 'memory':
#     346             # these gates are sigmoid-applied ones for equation 7
# --> 347             input_gate, forget_gate = self.create_gates(inputs_reshape, memory)
#     348             # equation 7 calculation
#     349             next_memory = input_gate * torch.tanh(next_memory)
#
# /nfs/undergrad/05/b05902026/Summarization-Lab/BIG-BIRD/RelationalMemory.py in create_gates(self, inputs, memory)
#     264             gate_inputs = self.input_gate_projector(inputs)
#     265             gate_inputs = gate_inputs.unsqueeze(dim=1)
# --> 266             gate_memory = self.memory_gate_projector(memory)
#     267         else:
#     268             raise ValueError("input shape of create_gate function is 2, expects 3")
#
# /usr/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# /usr/lib/python3.7/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      90     @weak_script_method
#      91     def forward(self, input):
# ---> 92         return F.linear(input, self.weight, self.bias)
#      93
#      94     def extra_repr(self):
#
# /usr/lib/python3.7/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1406         ret = torch.addmm(bias, input, weight.t())
#    1407     else:
# -> 1408         output = input.matmul(weight.t())
#    1409         if bias is not None:
#    1410             output += bias
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(range(len(all_loss)), all_loss)
plt.show()

# %%
#print(model.all_rewards)
#plt.plot(range(len(model.all_rewards)), model.all_rewards)

# %%
#plt.plot(range(len(model.all_rewards)-1), [sum(model.all_rewards[:i])/i for i in range(1,len(model.all_rewards))])

# %%
# if appear [enforce fail at CPUAllocator.cpp:56], it means cutoffs of adaptive softmax is too big
