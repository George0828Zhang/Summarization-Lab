# %%
from transformer_BigBirdA2C_GumbelSoftmax import *
from dataset import make_data_generator
import json
from tqdm import tqdm_notebook as tqdm
#from torchsummary import summary

# %%
folder = 'data/food/'
data_name = folder+'data.json'
# validation_name = folder+'valid_seq.json'
# testdata_name = folder+'testdata_seq.json'
vocab_name = folder+'vocab.json'

# %%
num_epochs = 10
save_rate = 1 #how many epochs per modelsave
#continue_from = "trained/Model1" # if none, put None
continue_from = None
epsilon = 1e-8
validation_size = 10000
device = torch.device('cuda')
# !mkdir -p trained

# %%
vocab = json.load(open(vocab_name, 'r'))
VOC_SIZE = len(vocab)
INPUT_MAX = 100
SUMM_MAX = 20
UNK = "[UNK]"
BOS = "[CLS]"
EOS = "[SEP]"
PAD = "[PAD]"

# %%
batch_size = 16

training_set, training_generator = make_data_generator(\
data_name, INPUT_MAX, SUMM_MAX, vocab[PAD], batch_size, cutoff=None, shuffle=True, num_workers=4)

# validation_set, validation_generator = make_data_generator(\
# validation_name, INPUT_MAX, OUTPUT_MAX, vocab[PAD], batch_size, cutoff=validation_size, shuffle=False, num_workers=4)

def data_gen_train():
    for src, label, tgt in training_generator:
        src = src.to(device)
        label = (label).long().to(device)
        tgt = tgt.to(device)
        b = Batch(src, tgt, vocab[PAD])
        b.label = label
        yield b
# Out:
# loading json
# load json done.
# HBox(children=(IntProgress(value=0, max=568454), HTML(value='')))

# %%
import math
total_train = int(math.ceil(training_set.size / batch_size))
# total_valid = int(math.ceil(validation_set.size / batch_size))
# print(total_train, total_valid)

# %%
def init_param(model):
    for p in model.parameters():
        if p.dim() > 1:
            nn.init.xavier_uniform_(p)

def make_big_bird(vocab, N=6, 
               d_model=512, d_ff=2048, h=8, dropout=0.1, emb_share=False, bert_share=False):
    "Helper: Construct a model from hyperparameters."
    
    vocab_sz = len(vocab)
    
    c = copy.deepcopy
    attn = MultiHeadedAttention(h, d_model)
    ff = PositionwiseFeedForward(d_model, d_ff, dropout)
    position = PositionalEncoding(d_model, dropout)
    
    src_emb = nn.Sequential(Embeddings(d_model, vocab_sz), c(position))
    if emb_share:        
        tgt_emb = src_emb
        bert_class_emb = src_emb
        bert_discr_emb = src_emb
    else:
        tgt_emb = nn.Sequential(Embeddings(d_model, vocab_sz), c(position))
        bert_class_emb = nn.Sequential(Embeddings(d_model, vocab_sz), c(position))
        bert_discr_emb = nn.Sequential(Embeddings(d_model, vocab_sz), c(position))
    
    
    bert_class = BERT(
        Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N),
        bert_class_emb,
        vocab[PAD]
    )
    
    if bert_share:
        bert_discr = bert_class
    else:
        bert_discr = BERT(
            Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N),
            bert_discr_emb,
            vocab[PAD]
        )
    
    translator = Translator(
        Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N),
        Decoder(DecoderLayer(d_model, c(attn), c(attn), 
                             c(ff), dropout), N),
        src_emb,
        tgt_emb,
        Generator(d_model, vocab_sz, device),
        CriticNet(d_model)
        )
    
#     classifier = Classifier(
#         bert_class,
#         out_class = 5
#         # criterion = BCE
#     )
        
    discriminator = Discriminator(
        Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N),
        d_model,
        len(vocab),
        vocab[PAD]
    )

    reconstructor = Reconstructor(
        Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N),
        Decoder(DecoderLayer(d_model, c(attn), c(attn), 
                             c(ff), dropout), N),
        src_emb,
        tgt_emb,
        Generator(d_model, vocab_sz, device),
        vocab[PAD]
    )
    # This was important from their code. 
    # Initialize parameters with Glorot / fan_avg.
    for m in [translator, reconstructor, discriminator]:
        init_param(m)
        
#     if(str(device) == 'cpu'):
#         savedmodel = torch.load("pretrained/Translator4", map_location=lambda storage, location: storage)
#     else:
#         savedmodel = torch.load("pretrained/Translator4")
#     translator.load_state_dict(savedmodel['model'], strict=False)
#     if(str(device) == 'cpu'):
#         savedmodel = torch.load("pretrained/Translator4", map_location=lambda storage, location: storage)
#     else:
#         savedmodel = torch.load("pretrained/Translator4")
#     reconstructor.load_state_dict(savedmodel['model'])#, strict=False)
            
    # creation of big bird
    model = BigBird(
        translator, discriminator, reconstructor , 
        vocab, gamma=0.99, clip_value=0.1, #for WGAN, useless if WGAN-GP is used 
        lr_G = 5e-5,
        lr_D = 1e-4,
        lr_R = 2e-5,
        LAMBDA = 10, # Gradient penalty lambda hyperparameter
        RL_scale = 1,
        device = device
    )

    return model

# %%
model = make_big_bird(vocab, N=4, d_model=128, d_ff=256, h=4, dropout=0.1, emb_share=True, bert_share=True)
#model.load("Nest/NewbornBirdA2C_GumbelSoftmax")

# %%
vocab_inv = {a:b for b, a in vocab.items()}
def convert_ids_to_tokens(ids):
    return [vocab_inv[i] for i in ids]

# %%
start = 1 if continue_from == None else (int(continue_from.split("Model")[-1])+1)
history = []


from tensorboardX import SummaryWriter
writer = SummaryWriter('mygraph')

all_loss = []
all_reward = []

for epoch in range(start, num_epochs+1):
    print("Epoch", epoch)
    
    # training
    stats = Stats()
    model.train()
    
    rewards = []
    
    trange = tqdm(enumerate(data_gen_train()), total=total_train)
    for i, batch in trange:
        loss, score  = model.run_iter(batch.src, batch.src_mask, SUMM_MAX, batch.trg, writer, D_iters=5, verbose = 1)
        trange.set_postfix(
            **{'RL_loss': '{:.3f}'.format(loss[0])},
            **{'G_loss': '{:.3f}'.format(loss[1])},
            **{'D_loss': '{:.3f}'.format(loss[2])},
            **{'real_score': '{:.3f}'.format(score[0])},
            **{'fake_score': '{:.3f}'.format(score[1])},
            **{'acc': '{:.3f}'.format(score[2])},
            **{'reward':'{:.3f}'.format(score[3])}
        )
        stats.update(sum(loss), 1, log=0)
        rewards.append(score[3])
        
    t_h = stats.history
    history.append(t_h)
    writer.add_scalar('reward', np.mean(t_h), epoch)
    print("[info] epoch train loss:", np.mean(t_h))
    print("[info] epoch train reward:", sum(rewards)/len(rewards))
    all_loss.append(np.mean(t_h))
    all_reward.append(sum(rewards)/len(rewards))
writer.close()  
#     try:
#         torch.save({'model':model.state_dict(), 'training_history':t_h, 'validation_loss':np.mean(v_h)}, 
#                    "trained/Model"+str(epoch))
#     except:
#         continue
# Out:
# Epoch 1
# HBox(children=(IntProgress(value=0, max=35529), HTML(value='')))
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'after', 'one', 'of', 'my', 'cats', 'experienced', 'some', 'tu', '##mmy', 'problems', ',', 'i', 'decided', 'to', 'look', 'for', 'some', 'grain', 'free', 'options', '.', 'my', 'cats', 'love', 'this', 'stuff', '.', 'i', "'", 've', 'tried', 'several', 'flavors', ',', 'and', 'they', 'like', 'them', 'all', '.', 'they', 'are', 'excited', 'again', 'at', 'meal', 'time', '.', 'the', 'best', 'benefit', 'is', 'that', 'the', '"', 'tu', '##mmy', 'problems', '"', 'are', 'so', 'much', 'better', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# summary:
# ['[CLS]', 'die', 'practical', 'bikes', '##tology', 'beat', 'identifiable', 'not', 'mahogany', 'sense', 'see', 'racehorse', 'roma', 'গ', 'circumstances', '[unused502]', 'livestock', '117', 'austen', 'growling', 'jimmie']
# real summary:
# ['[CLS]', 'cats', 'love', 'it', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
#
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'maybe', 'it', "'", 's', 'my', 'dogs', 'who', 'seem', 'to', 'prefer', 'chew', '##y', 'type', 'treats', 'over', 'hard', 'cookies', 'but', 'they', 'have', 'little', 'to', 'no', 'interest', 'in', 'these', 'although', 'they', 'seem', 'to', 'be', 'a', 'healthy', 'product', '.', 'they', 'will', 'eat', 'a', 'few', 'here', 'and', 'there', 'when', 'they', 'get', 'hungry', 'enough', 'but', 'otherwise', 'pass', 'in', 'hopes', 'of', 'getting', 'their', 'chew', '##y', 'treats', 'instead', '.', 'but', 'don', "'", 't', 'let', 'my', 'dogs', "'", 'taste', 'and', 'preferences', 'influence', 'your', 'decision', '.', 'their', 'ingredients', 'are', 'healthy', 'and', 'the', 'amount', 'you', 'get', 'for', 'the', 'price', 'is', 'unbelievable', '.', 'crunch', '##y', 'is', 'always', 'better', 'for', 'the', 'health']
# summary:
# ['[CLS]', 'repeat', 'found', 'beat', 'yet', 'big', 'techno', 'bar', '##fall', 'su', 'dog', 'brew', 'virgin', 'care', 'vanilla', '##shi', 'with', 'older', 'snacks', 'sugar', 'english']
# real summary:
# ['[CLS]', 'dogs', 'don', "'", 't', 'eat', 'them', 'much', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# [',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',']
#
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'i', 'buy', 'this', 'in', 'the', 'uk', 'but', 'it', 'is', 'wonderful', 'to', 'know', 'i', 'can', 'get', 'it', 'here', 'if', 'supplies', 'run', 'low', 'between', 'trips', '!', 'i', 'recommend', 'steep', '##ing', 'the', 'bag', 'for', 'several', 'minutes', ',', 'then', 'adding', 'milk', 'and', 'sugar', 'to', 'taste', '.', 'it', 'has', 'been', 'a', 'life', '##sa', '##ver', 'during', 'cold', 'and', 'flu', 'season', '.', 'i', 'prefer', 'it', 'to', 'pg', 'tips', ',', 'which', 'i', 'find', 'to', 'be', 'quite', 'bitter', '.', 'ty', '##ph', '##oo', 'has', 'a', 'much', 'smooth', '##er', 'taste', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# summary:
# ['[CLS]', 'sensation', '##igo', 'its', '##es', 'distances', '.', 'date', 'margarita', 'even', 'belly', '##gard', 'please', 'radiation', 'bit', 'selection', 'and', 'price', 'extreme', 'only', '##berry']
# real summary:
# ['[CLS]', 'best', 'dec', '##af', 'hot', 'tea', 'i', 'have', 'tasted', '!', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# [',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',']
#
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'better', 'than', 'the', 'real', 'thing', '.', 'crunch', '##y', 'texture', '.', 'hint', 'of', 'butter', '##y', 'taste', 'and', 'just', 'the', 'right', 'amount', 'of', 'salt', '.', 'can', "'", 't', 'beat', 'the', 'price', ',', 'either', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# summary:
# ['[CLS]', 'explanation', 'soup', '##vana', 'as', 'fruit', 'amalgamated', '[unused937]', 'quickly', 'noted', 'intervene', 'fruit', 'radiation', 'quickly', '##ve', 'local', '##vana', 'easton', '##rra', 'monster', '##vana']
# real summary:
# ['[CLS]', 'yu', '##mmy', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# [',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',']
#
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'the', 'only', 'reason', 'i', 'bought', 'these', 'beans', 'is', 'because', 'they', 'use', 'bp', '##a', 'free', 'cans', '.', 'the', 'beans', 'are', 'quite', 'gross', 'on', 'their', 'own', ',', 'but', 'when', 'you', 'cook', 'it', ',', 'it', 'tastes', 'a', 'lot', 'better', '.', 'who', 'eats', 'beans', 'straight', 'out', 'of', 'the', 'can', 'anyway', '##s', '?', 'otherwise', ',', 'great', 'healthy', 'product', 'in', 'bp', '##a', 'free', 'can', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# summary:
# ['[CLS]', 'amalgamated', 'fruit', 'item', 'quickly', 'markus', 'fruit', 'even', 'quickly', 'fruit', 'fruit', 'soup', 'quickly', 'fruit', 'intervene', 'quickly', 'markus', 'fruit', 'item', 'quickly', 'only']
# real summary:
# ['[CLS]', 'great', 'bp', '##a', 'free', 'beans', '!', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# [',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',']
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'love', 'the', 'cherry', '##heads', '.', 'only', 'complaint', 'is', 'retail', 'is', '.', '25', 'per', 'box', 'x', '24', 'quantity', '=', '6', '.', '00', 'paid', 'almost', 'double', 'retail', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# summary:
# ['[CLS]', 'skyscraper', 'employee', 'judging', 'easton', 'clasp', 'skyscraper', '!', 'employee', 'radiation', 'clasp', 'employee', 'employee', 'employee', 'fruit', 'fruit', 'radiation', 'employee', 'employee', 'quickly', 'skyscraper']
# real summary:
# ['[CLS]', 'cherry', '##heads', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# [',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',']
#
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'they', 'arrived', 'in', 'perfect', 'condition', ',', 'unlike', 'my', 'previous', 'purchase', 'of', 'the', 'same', 'product', '!', 'great', 'product', ',', 'thank', 'you', 'for', 'making', 'them', 'available', '.', 'lynn', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# summary:
# ['[CLS]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', 'fruit', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '!', 'cid', '[PAD]', '[PAD]']
# real summary:
# ['[CLS]', 'g', '/', 'f', 'pre', '##tze', '##ls', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# [',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',']
#
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'the', 'coffee', 'had', 'a', 'nice', 'bold', ',', 'flavor', ',', 'but', 'the', 'foil', 'on', 'the', 'cups', 'were', 'not', 'properly', 'sealed', ',', 'and', 'i', 'mean', 'all', 'of', 'the', 'cups', '.', 'every', 'brewing', 'left', 'grounds', 'in', 'the', 'cup', 'and', 'sometimes', 'made', 'a', 'complete', 'mess', 'because', 'the', 'water', 'wasn', "'", 't', 'going', 'through', 'the', 'brew', 'tip', '.', 'the', 'flavor', 'of', 'the', 'coffee', 'was', 'not', 'enough', 'to', 'warrant', 'a', 'better', 'rating', 'because', 'we', 'get', 'this', 'product', 'for', 'convenience', 'and', 'easy', 'clean', 'up', ',', 'as', 'much', 'as', 'for', 'the', 'flavor', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# summary:
# ['[CLS]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', 'fruit', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# real summary:
# ['[CLS]', 'defective', 'seal', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# [',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',']
#
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'this', 'is', 'our', 'first', 'for', '##ay', 'into', 'roast', '##ing', 'our', 'own', 'beans', '-', 'and', ',', 'i', 'admit', ',', 'done', 'by', 'accident', '.', 'i', 'put', 'this', 'bag', 'in', 'my', 'cart', 'when', 'i', 'was', 'buying', 'a', 'number', 'of', 'varieties', 'to', 'see', 'if', 'i', 'could', 'get', 'some', 'good', 'es', '##press', '##o', 'from', 'amazon', '.', 'it', 'was', 'with', 'some', 'serious', 'humble', 'equipment', 'that', 'i', 'tried', 'roast', '##ing', 'first', 'a', 'small', 'batch', 'on', 'the', 'pan', ',', 'then', 'another', 'small', 'batch', 'in', 'the', 'oven', '.', 'the', 'oven', 'batch', 'turned', 'out', 'much', 'more', 'even', '.', '<', 'br', '/', '>', '<', 'br', '/', '>', 'initially', 'i', 'wasn']
# summary:
# ['[CLS]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# real summary:
# ['[CLS]', 'really', 'good', ',', 'even', 'with', 'humble', 'roast', '##ing', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# [',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',']
#
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'this', 'tea', 'is', 'a', 'disappointment', 'because', 'its', 'flavour', '##s', 'are', 'weak', '.', 'it', 'takes', 'about', 'double', 'the', 'amount', 'suggested', 'to', 'brew', 'a', 'proper', 'pot', '.', 'the', 'packaging', 'is', 'green', ',', 'but', 'that', 'does', 'not', 'make', 'up', 'for', 'the', 'weak', 'tea', 'inside', '.', 'if', 'you', 'do', 'not', 'like', 'a', 'strong', ',', 'traditional', 'berg', '##amo', '##t', 'flavour', ',', 'then', 'try', 'this', 'one', '.', 'you', 'might', 'like', 'it', ',', 'but', 'i', 'did', 'not', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# summary:
# ['[CLS]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', 'grape', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# real summary:
# ['[CLS]', 'weak', 'earl', 'grey', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# [',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',']
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'unfortunately', ',', 'i', 'somehow', 'stumbled', 'upon', 'this', 'product', 'and', ',', 'based', 'on', 'all', 'the', 'glowing', 'reviews', ',', 'bought', 'a', 'case', '.', 'upon', 'opening', 'the', 'first', 'bag', 'and', 'eating', 'a', 'couple', ',', 'i', 'was', 'disgusted', 'by', 'the', 'taste', '.', 'worst', 'thing', 'i', "'", 've', 'ever', 'ordered', 'from', 'amazon', '-', '-', '-', 'and', 'i', "'", 've', 'ordered', 'a', 'lot', '.', 'i', 'don', "'", 't', 'think', 'the', 'nutritional', 'values', 'are', 'all', 'that', 'great', ',', 'either', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# summary:
# ['[CLS]', '[PAD]', '[PAD]', 'grape', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# real summary:
# ['[CLS]', 'to', 'me', ',', '"', 'original', '"', 'flavor', 'just', 'nasty', 'tasting', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# [',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',']
#
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'my', 'two', 'cat', 'en', '##oy', 'this', 'canned', 'food', '.', 'they', 'come', 'running', 'as', 'i', 'get', 'it', 'out', 'of', 'the', 'cabinet', '.', 'i', 'recommend', 'this', 'canned', 'cat', 'food', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# summary:
# ['[CLS]', '[PAD]', 'only', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', 'grape', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# real summary:
# ['[CLS]', 'smells', 'like', 'real', 'food', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# [',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',']
#
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'i', 'was', 'on', 'the', 'lookout', 'for', 'gran', '##ola', 'bars', 'that', 'have', 'ingredients', 'that', 'are', 'more', 'natural', '.', 'i', 'used', 'to', 'love', 'nature', 'valley', 'bars', ',', 'then', 'i', 'fell', 'in', 'love', 'with', 'the', 'fiber', '##one', 'bars', ',', 'then', 'i', 'inhaled', 'balance', 'bars', '.', 'now', 'i', 'think', 'i', "'", 've', 'settled', 'on', 'lara', '##bar', '##s', ',', 'simply', 'because', 'they', 'have', 'such', 'few', 'ingredients', 'and', 'i', 'can', 'pro', '##no', '##unce', 'every', 'single', 'one', 'of', 'them', '.', 'even', 'better', ',', 'i', 'can', 'go', 'to', 'a', 'regular', 'grocery', 'store', 'and', 'buy', 'the', 'ingredients', ',', 'and', 'if', 'i', "'", 'd', 'want', 'to', 'spend', 'more', 'time']
# summary:
# ['[CLS]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', 'only', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# real summary:
# ['[CLS]', 'super', 'ta', '##sty', ',', 'pro', '##no', '##unce', '##able', 'ingredients', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# ['the', ',', ',', ',', ',', ',', 'to', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',']
#
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'seriously', ',', 'you', 'don', "'", 't', 'want', 'to', 'live', 'without', 'it', '.', 'this', 'sauce', 'is', 'not', 'that', 'hot', '-', 'well', ',', 'it', 'is', 'hot', ',', 'but', 'it', 'is', 'also', 'full', 'of', 'flavor', ',', 'it', 'goes', 'on', 'just', 'about', 'everything', '.', 'i', 'keep', 'a', 'bottle', 'at', 'work', 'as', 'well', ',', 'it', 'makes', 'even', 'so', '-', 'so', 'lunch', 'taste', 'better', '.', 'i', 'say', 'even', 'if', 'you', 'don', "'", 't', 'like', 'hot', 'food', ',', 'give', 'this', 'a', 'try', '-', 'it', 'will', 'grow', 'on', 'you', '.', 'maybe', 'you', 'should', 'not', 'start', 'with', '12', '28', '-', 'oz', 'bottles', ',', 'but', 'give', 'it', 'a', 'try']
# summary:
# ['[CLS]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', 'cid', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# real summary:
# ['[CLS]', 'the', 'very', 'best', '.', '.', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# [',', ',', ',', ',', ',', ',', ',', ',', 'to', 'to', ',', 'to', ',', 'to', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'the', ',', ',', ',', ',', ',', ',', ',', ',']
#
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'although', 'i', 'knew', 'that', 'ginger', 'snaps', 'were', 'supposed', 'to', 'be', 'hard', ',', 'i', 'was', 'surprised', 'by', 'how', 'much', 'so', 'these', 'newman', "'", 's', 'own', 'organic', '##s', 'ginger', 'snaps', 'cookies', 'were', 'when', 'i', 'first', 'bit', 'down', 'on', 'one', 'with', 'my', 'front', 'teeth', '.', 'it', 'hurt', 'my', 'teeth', '.', 'but', 'i', 'quickly', 'adapted', 'by', 'shoving', 'them', 'deep', 'into', 'my', 'cheek', 'and', 'bit', 'down', 'with', 'my', 'mo', '##lars', '.', 'i', 'like', 'them', '.', 'they', 'have', 'a', 'very', 'strong', 'ginger', 'favor', 'and', 'i', 'am', 'a', 'ginger', 'root', 'lover', ',', 'and', 'they', 'are', 'not', 'overly', 'sweet', '.', 'i', 'liked', 'them', 'so', 'much', 'that', 'i']
# summary:
# ['[CLS]', '[PAD]', '[PAD]', '[PAD]', 'cid', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# real summary:
# ['[CLS]', 'hard', 'but', 'delicious', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# ['the', 'the', 'the', ',', ',', ',', ',', ',', ',', ',', ',', 'the', ',', 'to', 'the', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',']
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'well', ',', 'first', 'of', 'all', ',', 'if', 'you', 'are', 'already', 'planning', 'on', 'getting', 'a', 'x', '##yl', '##ito', '##l', 'sweet', '##ener', 'anyway', ':', 'emerald', 'forest', 'is', 'made', 'in', 'the', 'usa', 'from', 'american', 'grown', 'birch', 'trees', ',', 'unlike', 'most', 'other', 'brands', 'which', ',', 'of', 'course', ',', 'come', 'from', 'china', '.', 'and', ',', 'as', 'i', "'", 'm', 'sure', 'you', 'realize', ',', 'if', 'every', 'american', 'bought', 'only', '$', '65', 'more', 'per', 'year', 'in', 'american', 'products', ',', 'we', 'would', 'produce', 'literally', 'hundreds', 'of', 'thousands', 'of', 'new', 'jobs', '(', 'that', 'is', 'not', 'an', 'ex', '##agger', '##ation', ',', 'but', 'rather', 'an', 'estimation', ',', 'as', 'i', 'cannot']
# summary:
# ['[CLS]', '[PAD]', '[PAD]', '[PAD]', 'cid', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# real summary:
# ['[CLS]', 'yes', '~', '!', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# ['the', 'the', 'the', 'to', 'to', 'to', 'to', ',', 'to', 'to', ',', 'to', 'the', ',', ',', 'to', 'to', 'to', 'the', ',', ',', ',', ',', ',', ',', 'the', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',']
#
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'this', 'is', 'a', 'really', 'good', 'tea', '.', 'even', 'though', 'doctors', 'say', 'don', "'", 't', 'give', 'any', 'water', 'to', 'babies', 'under', '4', 'month', 'i', 'gave', 'my', 'first', 'daughter', 'this', 'drink', 'since', '1', 'month', '.', 'she', 'was', 'very', 'gas', '##sy', 'and', 'this', 'drink', 'helped', 'her', 'a', 'little', '.', 'sometimes', 'i', 'was', 'given', 'it', 'to', 'her', 'instead', 'of', 'water', 'and', 'she', 'loved', 'it', '.', 'they', 'also', 'have', 'other', 'flavors', 'too', '.', 'highly', 'recommended', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# summary:
# ['[CLS]', '[PAD]', 'potatoes', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# real summary:
# ['[CLS]', 'best', 'product', '!', '!', '!', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# [',', ',', 'the', 'the', 'the', ',', 'the', ',', 'the', ',', 'the', ',', ',', ',', ',', ',', 'the', 'the', 'the', ',', ',', ',', ',', ',', ',', ',', ',', 'the', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',']
#
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'i', 'expected', 'this', 'product', 'to', 'be', 'similar', 'to', 'those', 'sold', 'by', 'mrs', '.', 'may', "'", 's', '.', 'what', 'a', 'disappointment', '!', 'they', 'are', 'very', 'salty', '.', 'imagine', 'taste', 'combination', 'of', 'salt', 'and', 'sugar', '.', 'the', 'bag', 'is', 'going', 'back', 'to', 'cost', '##co', '.', 'i', 'would', 'not', 'eat', 'another', 'piece', ',', 'even', 'if', 'it', 'is', 'free', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# summary:
# ['[CLS]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '!', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# real summary:
# ['[CLS]', 'very', 'salty', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# [',', ',', ',', 'the', 'the', ',', ',', ',', 'the', ',', ',', 'the', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', '.', ',', ',', ',', ',', ',', ',', '.', '.', ',', ',', ',', ',', '.', ',', ',', ',', '.', '.', '.', ',', ',', '.', '.', '.', ',', ',', ',']
#
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'this', 'does', 'not', 'taste', 'like', 'pep', '##eron', '##i', '.', 'more', 'like', 'slim', 'jim', ',', 'except', 'this', 'uses', 'real', 'sausage', 'cas', '##ing', '(', 'slim', 'jim', 'uses', 'paper', '.', '.', '.', 'sh', '##hh', '.', ')', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# summary:
# ['[CLS]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# real summary:
# ['[CLS]', 'at', 'least', 'it', "'", 's', 'not', 'slim', 'jim', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# ['the', 'the', 'the', ',', ',', 'the', ',', 'the', 'the', 'the', ',', 'the', 'the', 'the', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'the', ',', ',', ',', 'the', 'the', 'the', 'the', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', '.', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'the', ',']
#
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'after', 'reading', 'the', 'other', 'reviews', ',', 'i', "'", 'm', 'confused', 'and', 'don', "'", 't', 'think', 'that', 'anyone', 'was', 'talking', 'about', 'this', 'tea', '!', '(', 'sounded', 'like', 'most', 'comments', 'per', '##tained', 'to', 'prince', 'of', 'peace', 'green', 'tea', ',', 'and', 'don', "'", 't', 'have', 'anything', 'to', 'do', 'with', 'the', 'instant', 'dong', 'qu', '##ai', 'and', 'red', 'date', 'tea', 'that', 'i', 'clicked', 'on', '.', '.', '.', 'that', 'being', 'said', ',', 'this', 'is', 'a', 'remarkable', 'tea', '.', '.', '.', 'it', "'", 's', 'delicious', ',', 'it', "'", 's', 'instant', '(', 'so', 'you', 'don', "'", 't', 'have', 'to', 'wait', 'for', 'it', 'to', 'steep', ')', 'and', 'it']
# summary:
# ['[CLS]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', 'grape']
# real summary:
# ['[CLS]', 'such', 'a', 'special', 'gem', ',', 'this', 'one', '!', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# [',', ',', 'the', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', '.', ',', ',', ',', ',', ',', ',', ',', ',', '.', '.', '.', ',', '.', ',', '.', ',', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'this', 'is', 'a', 'nice', 'package', 'of', 'starbucks', 'varieties', '.', 'it', 'is', 'hard', 'to', 'find', 'a', 'package', 'like', 'this', '.', 'received', 'everything', 'as', 'advertised', '.', 'no', 'worries', 'at', 'all', '!', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# summary:
# ['[CLS]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', 'grape', '[PAD]', '[PAD]']
# real summary:
# ['[CLS]', 'no', 'worries', '!', 'received', 'as', 'advertised', '.', 'great', 'variety', '!', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# [',', ',', 'the', 'the', 'the', 'the', ',', 'the', ',', 'the', ',', 'the', ',', ',', 'the', ',', ',', ',', 'the', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'the', ',', ',', ',', 'the', 'the', ',', ',', ',', ',', ',', ',', ',', ',', 'the', ',', 'the', ',', ',', 'the', 'the', 'the', ',', 'the', 'the', ',', 'the', 'the', 'the', 'the', ',', ',', ',', ',', ',', ',', 'the', 'the', 'the', ',', 'the', 'the', 'the', ',', 'the', ',', ',', ',', ',', ',', ',', 'the', 'the', 'the', 'the', 'the', 'the', 'the', ',', ',', 'the', 'the', 'the', ',', 'the', ',', 'the', 'the', ',', ',', 'the', 'the']
#
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'i', 'learned', 'recently', 'that', 'cats', 'are', 'not', 'supposed', 'to', 'have', 'grains', 'in', 'their', 'food', '.', 'it', 'causes', 'them', 'health', 'problems', ',', 'including', 'weight', 'problems', '.', 'the', 'first', 'few', 'days', 'of', 'trying', 'this', 'i', 'couldn', "'", 't', 'decide', 'if', 'they', 'were', 'liking', 'it', 'or', 'not', '.', 'they', 'had', 'always', 'eaten', 'dry', 'food', '.', 'after', 'a', 'few', 'days', 'on', 'this', 'canned', 'they', 'really', 'started', 'to', 'show', 'that', 'they', 'were', 'liking', 'it', '.', 'it', 'is', 'a', 'little', 'chunk', '##y', ',', 'but', 'the', 'chunks', 'are', 'easily', 'smoothed', 'out', '-', 'it', "'", 's', 'also', 'better', 'to', 'add', 'some', 'warm', 'water', 'with', 'this', 'to', 'make']
# summary:
# ['[CLS]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', 'grape', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# real summary:
# ['[CLS]', 'they', 'like', 'it', '!', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# [',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', '.', '.', ',', '.', ',', '.', '.', '.', ',', ',', '.', ',', '.', ',', ',', '.', ',', '.', ',', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
#
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'as', 'always', 'buying', 'through', 'amazon', 'is', 'so', 'easy', 'and', 'service', 'is', 'always', 'good', '.', 'the', 'only', 'reason', 'that', 'i', 'didn', "'", 't', 'give', 'it', '5', 'stars', 'is', 'because', 'i', 'haven', "'", 't', 'actually', 'used', 'the', 'product', 'yet', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# summary:
# ['[CLS]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '!', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# real summary:
# ['[CLS]', 'smoked', 'pa', '##pr', '##ika', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# ['the', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'the', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'the', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'the', ',', 'the', 'the', ',', ',', ',', ',', ',', 'the', ',', 'the', 'the', ',', ',', 'the', ',', 'the', 'the', 'the', 'the', 'the', 'the', ',', 'the', ',', ',', 'the', ',', 'the', 'the', 'the', 'the', ',', 'the', 'the', 'the', 'the', ',', ',', 'the', 'the', ',', ',', ',', ',', ',', 'the', 'the', ',', 'the', 'the', 'the', ',']
#
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'these', 'chips', 'are', 'great', '!', 'they', 'look', 'almost', 'like', 'a', 'flattened', 'rice', 'cake', ',', 'but', 'taste', 'so', 'much', 'better', ',', 'more', 'like', 'a', 'potato', 'chip', '.', 'the', 'bb', '##q', 'flavor', 'is', 'delicious', '.', 'they', 'are', 'very', 'low', 'in', 'fat', 'and', 'full', 'of', 'flavor', '.', 'it', 'is', 'easy', 'to', 'eat', 'an', 'entire', 'bag', 'of', 'these', '!', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# summary:
# ['[CLS]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', 'grape', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# real summary:
# ['[CLS]', 'healthy', 'and', 'delicious', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# [',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'the', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'the', ',', ',', ',', ',', ',', 'the', ',', ',', ',', ',', ',', '.', 'the', 'the', 'the', ',']
#
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'due', 'to', 'all', '##er', '##gies', 'on', 'the', 'part', 'of', 'one', 'dog', ',', 'and', 'pick', '##iness', 'on', 'the', 'part', 'of', 'the', 'other', ',', 'i', "'", 've', 'switched', 'to', 'natural', 'dog', 'food', 'over', 'the', 'past', 'year', '.', 'of', 'them', 'all', ',', 'my', 'dogs', 'love', 'this', 'stuff', 'the', 'best', '.', 'it', 'has', 'a', 'nice', 'smell', 'and', 'texture', ',', 'and', 'is', 'more', 'easily', 'chewed', 'by', 'the', 'elderly', 'dog', '.', 'relatives', 'who', 'hadn', "'", 't', 'seen', 'the', 'dogs', 'for', 'a', 'few', 'months', 'immediately', 'commented', 'on', 'the', 'health', '##ier', 'appearance', 'and', 'renewed', 'vigor', 'of', 'the', 'dogs', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# summary:
# ['[CLS]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', 'item', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# real summary:
# ['[CLS]', 'the', 'best', 'so', 'far', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# [',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'the', ',', ',', 'the', 'the', ',', ',', ',', 'the', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'the', ',', ',']
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'we', 'have', 'ordered', 'these', 'bags', 'a', 'couple', 'of', 'times', 'and', 'we', 'do', 'not', 'have', 'any', 'complaints', '!', 'we', 'like', 'that', 'they', 'are', 'bio', '##de', '##grad', '##able', 'and', 'the', 'size', 'is', 'perfect', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# summary:
# ['[CLS]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# real summary:
# ['[CLS]', 'excellent', 'bags', '!', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# [',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'the', ',', ',', 'the', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'the', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'the', ',', ',', ',', ',', ',', ',']
#
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'not', 'much', 'to', 'say', 'i', 'buy', 'this', 'item', 'often', 'for', 'our', 'parrot', '##s', 'and', 'is', 'same', 'quality', 'but', 'for', 'much', 'less', 'money', 'than', 'we', 'were', 'used', 'to', 'paying', '.', 'nice', 'size', 'dice', 'good', 'quality', 'was', 'fresh', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# summary:
# ['[CLS]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', 'real', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# real summary:
# ['[CLS]', 'freeze', 'dried', 'papa', '##ya', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# [',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'the', ',', ',', 'the', ',', 'the', ',']
#
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'my', 'dogs', 'love', 'this', 'stuff', 'and', 'the', 'nutrient', 'profile', 'is', 'way', 'better', 'than', 'any', 'other', 've', '##g', 'dog', 'food', 'on', 'the', 'market', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# summary:
# ['[CLS]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', 'quickly', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# real summary:
# ['[CLS]', 'the', 'only', 'vegetarian', 'dog', 'food', 'to', 'use', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# [',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'the', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'the', 'the', 'the', ',', ',', ',', ',', ',', ',', ',', 'the', 'the', 'the', 'the', 'the', ',', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', ',', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', ',', 'the', 'the', 'the', 'the', 'the', 'the', ',', 'the', 'the', 'the', 'the', ',', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the']
#
# lay egg to ./Nest ... save as ./Nest/NewbornBirdA2C_GumbelSoftmax
# origin:
# ['[CLS]', 'i', 'picked', 'ras', '##berry', ',', 'blue', '##berry', ',', 'and', 'boys', '##en', '##berry', '.', 'all', 'were', 'good', ',', 'but', 'boys', '##en', '##berry', 'was', 'great', '.', '.', '.', '.', '.', '.', '.', 'will', 'order', 'more', 'soon', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# summary:
# ['[CLS]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', 'star', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# real summary:
# ['[CLS]', 'great', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# reconsturct out:
# [',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'the', ',']

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(range(len(all_reward)), all_reward)
plt.plot(range(len(all_loss)), all_loss)
plt.show()

# %%
#print(model.all_rewards)
#plt.plot(range(len(model.all_rewards)), model.all_rewards)

# %%
#plt.plot(range(len(model.all_rewards)-1), [sum(model.all_rewards[:i])/i for i in range(1,len(model.all_rewards))])
